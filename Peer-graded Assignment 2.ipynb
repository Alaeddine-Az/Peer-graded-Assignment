# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Alaeddine Azaiz** <br> Product Manager

# %% [markdown]
# *I am interested in data science because I see a future for AI and machine learning to dramatically transform the way we live and work. I want to be involved in making that future a reality.*

# %% [markdown]
# ### My code should calculate the product of 5 and 3

# %%
5*3
# Out:
# 15

# %% [markdown]
# * Bullet point
# * Anotherr bullet point
# * and anotherr bullet point
# ***
#
#
# 1. Numbered item one
# 2. Numbered item two
# 3. Numbered item three
#
# ***
# |Left |Center|Right|
# |:-|:-:|-:|
# |1 |A |C |
# |2 |B |D |
